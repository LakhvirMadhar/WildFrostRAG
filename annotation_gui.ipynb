# %%
from utils.evaluation_gui import QueryAnnotationGUI

# Ensure you have your queries.csv in the right place
gui = QueryAnnotationGUI(filepath='queries/simple_reference_based_queries.csv')
gui.display()
